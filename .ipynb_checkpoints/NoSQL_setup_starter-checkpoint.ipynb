# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray D:\Data_Boot_Camp\Module_12_challenge\nosql-challenge\Resources\establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'classDB', 'config', 'fruits_db', 'gardenDB', 'local', 'met', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'The Pines Garden',
#  'AddressLine2': 'Beach Road',
#  'AddressLine3': 'St Margarets Bay',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pines Calyx',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4587.362402580997,
#  'FHRSID': 254250,
#  'LocalAuthorityBusinessID': 'PI/000066174',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DZ',
#  'RatingDate': '2021-08-17T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6663ecde6d78d51a3c05c3b6'),
#  'geocode': {'latitude': '51.148133', 'longitude': '1.383298'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/254250',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restaurant)
# Out:
# InsertOneResult(ObjectId('6663ecf05bab2b6afe2061f8'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
pprint(establishments.find_one(new_restaurant))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6663ecf05bab2b6afe2061f8'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
#Query
query = {'BusinessType': 'Restaurant/Cafe/Canteen'}
fields = {'BusinessTypeID': 1, 'BusinessType': 1}

# Cast the results as a list and save them to a variable
results = list(establishments.find(query, fields))

# Pretty print the results
pprint(results)
# Out:
# [{'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3b7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3b8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3ba')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3bb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3bd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3c1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3c4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3c5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3c7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3c8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3ca')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3cd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3d4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3d6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3d9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3e4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3e7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3e9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3ea')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3eb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3ec')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3f4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3f5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3f7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3f9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3fb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c3fe')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c401')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c404')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c405')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c406')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c408')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c40b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c40e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c40f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c410')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c41b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c41c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c41f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c420')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c421')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c425')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c427')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c42a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c42d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c435')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c437')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c43e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c43f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c441')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c442')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c443')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c444')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c44e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c454')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c455')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c457')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c45b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c45f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c460')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c463')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c464')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c465')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c470')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c473')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c477')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c478')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c47b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c47f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c484')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c487')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c48d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c493')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c497')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4a3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4a4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4a5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4a6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4b2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4b4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4b7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4b8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4ba')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4c7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4c8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4cd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4d3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4d6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4db')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4e0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4e1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4e6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4eb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4ed')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4ee')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4f2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4f8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4fc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4fd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c4ff')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c500')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c501')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c503')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c504')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c507')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c508')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c509')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c50a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c50b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c512')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c516')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c51e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c520')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c524')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c525')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c528')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c52d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c52f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c530')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c532')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c534')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c537')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c539')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c543')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c544')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c545')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c54f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c550')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c552')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c557')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c559')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c55d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c55f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c561')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c565')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c56c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c56e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c577')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c57d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c57e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c580')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c584')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c585')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c58a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c58c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c59b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c5a9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c5b0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c5cf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c5d3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c5db')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c5dc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c5df')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c5e3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c5f0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c605')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c61c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c61f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c62d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c62f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c630')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c632')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c641')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c64e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c64f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c654')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c657')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c658')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c65f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c660')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c662')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c668')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c66a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c66d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c670')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c67a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c67b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c681')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c68e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c691')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c693')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c698')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c69c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c6a9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c6ad')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c6b8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c6bd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c6c2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c6c6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c6c9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c6cc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c6cd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c6d1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c6d2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c6de')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c6e6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c6e8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c6ef')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c6f2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c6f4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c6f6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c6f9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c6fb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c700')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c701')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c705')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c709')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c70a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c70c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c710')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c712')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c714')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c715')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c716')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c71a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c724')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c725')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c727')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c72a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c72c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c72d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c731')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c733')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c737')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c739')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c73a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c73d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c741')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c743')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c744')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c745')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c74b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c74c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c74d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c755')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c758')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c75a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c75d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c760')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c761')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c763')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c76c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c76d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c76e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c774')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c776')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c77a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c77d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c780')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c782')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c784')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c786')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c787')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c78e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c78f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c790')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c791')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7a0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7a1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7a2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7a5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7a7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7a9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7ac')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7af')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7b0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7b1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7b3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7b4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7b7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7bb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7bd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7c1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7c7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7d2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7d5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7da')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7ec')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7ed')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7f1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7f7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7fb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c7fc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c813')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c819')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c81d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c81f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c820')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c822')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c825')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c82f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c830')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c831')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c832')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c834')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c835')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c837')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c838')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c83a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c83b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c83c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c83d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c844')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c84f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c853')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c854')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c855')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c856')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c857')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c858')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c85a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c85b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c85c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c860')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c863')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c864')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c867')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c86b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c872')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c873')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c874')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c875')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c87a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c87c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c87f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c884')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c886')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c889')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c88b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c88c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c893')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c896')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c899')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c89d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c89e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8a4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8a6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8ac')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8ad')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8af')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8b7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8b9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8be')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8c5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8ca')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8cc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8ce')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8d3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8d6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8d9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8e2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8e5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8e8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8e9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8ea')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8eb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8ee')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8f4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8f8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8f9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c8fb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c902')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c907')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c909')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c90f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c910')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c911')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c912')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c913')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c914')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c915')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c918')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c91a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c91b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c91c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c91d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c91e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c920')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c924')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c925')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c926')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c927')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c928')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c929')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c92a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c92c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c92d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c92f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c930')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c933')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c934')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c93d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c93e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c940')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c942')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c94a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c94b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c94e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c950')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c952')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c953')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c958')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c959')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c95b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c962')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c964')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c96f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c979')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c982')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c988')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c98b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c993')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ecde6d78d51a3c05c996')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
# ...
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d12')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d13')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d14')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d16')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d1a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d1c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d25')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d26')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d29')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d2d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d2e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d2f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d30')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d31')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d32')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d33')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d36')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d3a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d3b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d3c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d3d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d40')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d41')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d43')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d44')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d49')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d4f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d50')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d51')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d52')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d53')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d55')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d58')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d5b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d5c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d67')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d69')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d6d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d6f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d76')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d7e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d7f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d80')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d81')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065d8b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065dac')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065db4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065db8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065dba')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065dbb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065dbc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065dbe')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065dc1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065dc6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065dc7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065dc8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065dd1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065dd8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065ddf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065de1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065dea')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065dec')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065df1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065df2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065dff')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e01')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e06')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e08')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e0b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e0d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e0f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e14')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e16')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e28')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e2b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e34')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e35')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e3e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e42')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e47')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e4b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e4f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e54')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e56')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e58')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e5c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e65')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e66')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e68')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e69')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e6a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e6d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e6f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e70')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e72')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e74')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e77')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e78')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e79')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e7f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e80')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e81')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e83')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e84')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e86')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e87')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e89')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e8a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e92')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e93')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e97')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e98')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e9a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e9c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e9d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065e9e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065ea3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065eab')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065eae')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065eb8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065ebd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065ebf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065ec1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065ec4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065ed0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065ed1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065edc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065edd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065ee6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065ef3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065ef8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065efd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065f01')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065f06')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065f07')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065f12')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6663ece06d78d51a3c065f14')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': '',
#   '_id': ObjectId('6663ecf05bab2b6afe2061f8')}]

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
db.establishments.update_one({'BusinessName': 'Penang Flavours'}, {'$set': {'BusinessTypeID': 1}})
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
#Query
query = {'BusinessName': 'Penang Flavours'}

# Cast the results as a list and save them to a variable
results = list(establishments.find(query))

# Pretty print the results
pprint(results)
# Out:
# [{'AddressLine1': 'Penang Flavours',
#   'AddressLine2': '146A Plumstead Rd',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'BusinessName': 'Penang Flavours',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'Distance': 4623.972328074718,
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': True,
#   'Phone': '',
#   'PostCode': 'SE18 7DY',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6663ecf05bab2b6afe2061f8'),
#   'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#   'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}]

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"

# count number of local authority named as 'Dover'
result = establishments.count_documents({'LocalAuthorityName': 'Dover'})

# print the result
print(f'Number of establishments in Dover: {result}')
# Out:
# Number of establishments in Dover: 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({'LocalAuthorityName': 'Dover'})
# Out:
# DeleteResult({'n': 994, 'ok': 1.0}, acknowledged=True)

# %%
# Check if any remaining documents include Dover

# count number of local authority named as 'Dover'
result = establishments.count_documents({'LocalAuthorityName': 'Dover'})

# print the result
print(f'Number of establishments in Dover: {result}')
# Out:
# Number of establishments in Dover: 0

# %%
# Check that other documents remain with 'find_one'
pprint(establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6663ecde6d78d51a3c05c69c'),
#  'geocode': {'latitude': '51.083812', 'longitude': '1.195625'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [ {'$set': {"geocode.longitude" : {'$toDecimal' : '$geocode.longitude'}}},
                               {'$set': {"geocode.latitude" : {'$toDecimal' : '$geocode.latitude'}}}])
# Out:
# UpdateResult({'n': 38786, 'nModified': 38786, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 4091, 'nModified': 4091, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [{'$set': {"RatingValue" : {'$toInt' : '$RatingValue'}}}])
# Out:
# UpdateResult({'n': 38786, 'nModified': 34695, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Check that the coordinates and rating value are now numbers
# Define the fields to check
fields = {'geocode': 1, 'RatingValue': 1}

# Pretty print the results
pprint(establishments.find_one({},fields))
# Out:
# {'RatingValue': 5,
#  '_id': ObjectId('6663ecde6d78d51a3c05c69c'),
#  'geocode': {'latitude': Decimal128('51.083812'),
#              'longitude': Decimal128('1.195625')}}
